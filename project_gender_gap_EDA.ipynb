# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikikn/data-science-portfolio/blob/main/project_gender_gap_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install powerbiclient
from powerbiclient import Report, models
from powerbiclient.authentication import DeviceCodeLoginAuthentication
import pandas as pd

# %%
import pandas as pd

# %%
import pandas as pd

file_urls = [
    "https://gender-pay-gap.service.gov.uk/viewing/download-data/2017",
    "https://gender-pay-gap.service.gov.uk/viewing/download-data/2018",
    "https://gender-pay-gap.service.gov.uk/viewing/download-data/2019",
    "https://gender-pay-gap.service.gov.uk/viewing/download-data/2020",
    "https://gender-pay-gap.service.gov.uk/viewing/download-data/2021",
    "https://gender-pay-gap.service.gov.uk/viewing/download-data/2022",
    "https://gender-pay-gap.service.gov.uk/viewing/download-data/2023"
]

# Initialize an empty list to hold DataFrames
dfs = []

# Load and process each CSV file
for url in file_urls:
    # Load CSV
    df = pd.read_csv(url)

    # Extract the year from the URL
    year = int(url.split("/")[-1])

    # Add a 'Year' column with the extracted year
    df['Year'] = year

    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames
combined_data = pd.concat(dfs, ignore_index=True)

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59483 entries, 0 to 59482
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   EmployerName               59483 non-null  object
#  1   EmployerId                 59483 non-null  int64
#  2   Address                    59424 non-null  object
#  3   PostCode                   59252 non-null  object
#  4   CompanyNumber              51658 non-null  object
#  5   SicCodes                   55753 non-null  object
#  6   DiffMeanHourlyPercent      59483 non-null  float64
#  7   DiffMedianHourlyPercent    59483 non-null  float64
#  8   DiffMeanBonusPercent       47849 non-null  float64
#  9   DiffMedianBonusPercent     47847 non-null  float64
#  10  MaleBonusPercent           59483 non-null  float64
#  11  FemaleBonusPercent         59483 non-null  float64
#  12  MaleLowerQuartile          59089 non-null  float64
# ...

# %%
combined_data
# Out:
#                                       EmployerName  EmployerId  \
# 0                  "Bryanston School",Incorporated         676
# 1             "RED BAND" CHEMICAL COMPANY, LIMITED       16879
# 2                                123 EMPLOYEES LTD       17677
# 3                                     1610 LIMITED         682
# 4                   1879 EVENTS MANAGEMENT LIMITED       17101
# ...                                            ...         ...
# 59478                        YMCA ROBIN HOOD GROUP       22533
# 59479  York Teaching Hospital Nhs Foundation Trust       14029
# 59480                        ZANDRA RETAIL LIMITED       21420
# 59481           ZURICH EMPLOYMENT SERVICES LIMITED       14076
# 59482           ZURICH UK GENERAL SERVICES LIMITED       14078
#
#                                                  Address  PostCode  \
# 0           Bryanston House, Blandford, Dorset, DT11 0PX  DT11 0PX
# 1       19 Smith's Place, Leith Walk, Edinburgh, EH6 8NU   EH6 8NU
# ...

# %%
# Assuming combined_data is your DataFrame with the gender pay gap data
# Extract postcode area from PostCode column
combined_data['PostcodeArea'] = combined_data['PostCode'].str.extract(r'^([A-Z]{1,2})', expand=False)

# Load the CSV with postcode area mappings using a different encoding
postcode_area_mapping = pd.read_csv('/content/drive/MyDrive/Postcode outers  starter file.csv', encoding='latin1')

# Create a dictionary mapping postcode areas to regions
postcode_area_to_region = dict(zip(postcode_area_mapping['Postcode area'], postcode_area_mapping['Country']))

# Map postcode areas to regions
combined_data['Region'] = combined_data['PostcodeArea'].map(postcode_area_to_region)

# %%
postcode_area_mapping
# Out:
#     Postcode area Postcode area name   Country
# 0              AB           Aberdeen  Scotland
# 1              AL          St Albans   England
# 2               B         Birmingham   England
# 3              BA               Bath   England
# 4              BB          Blackburn   England
# ..            ...                ...       ...
# 116            WR          Worcester   England
# 117            WS            Walsall   England
# 118            WV      Wolverhampton   England
# 119            YO               York   England
# 120            ZE  Lerwick / Zetland  Scotland
#
# [121 rows x 3 columns]

# %%
combined_data.head(5)
# Out:
#                            EmployerName  EmployerId  \
# 0       "Bryanston School",Incorporated         676
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED       16879
# 2                     123 EMPLOYEES LTD       17677
# 3                          1610 LIMITED         682
# 4        1879 EVENTS MANAGEMENT LIMITED       17101
#
#                                              Address  PostCode CompanyNumber  \
# 0       Bryanston House, Blandford, Dorset, DT11 0PX  DT11 0PX      00226143
# 1   19 Smith's Place, Leith Walk, Edinburgh, EH6 8NU   EH6 8NU      SC016876
# 2          34 Roundhay Road, Leeds, England, LS7 1AB   LS7 1AB      10530651
# 3  Trinity Sports And Leisure, Chilton Street, Br...   TA6 3JA      06727055
# 4  The Sunderland Stadium Of Light, Sunderland, T...   SR5 1SU      07743495
#
#         SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 0          85310                   18.0                     28.2
# ...

# %%
# Assuming you have a column 'SicCodes' that contains the SIC codes
finance_sic_codes = ['64191']  # Add relevant SIC codes
combined_data = combined_data[combined_data['SicCodes'].isin(finance_sic_codes)]

# %%
combined_data
# Out:
#                                             EmployerName  EmployerId  \
# 247                                AIB GROUP (UK) P.L.C.       15495
# 291                                   Aldermore Bank PLC        1088
# 641                                        ATOM BANK PLC       16167
# 788    BANK OF AMERICA MERRILL LYNCH INTERNATIONAL LI...        1783
# 790                           BANK OF CHINA (UK) LIMITED        1784
# ...                                                  ...         ...
# 58136                            TRIODOS BANK UK LIMITED       22148
# 58167                                       TSB BANK PLC         355
# 58294                          UNITED TRUST BANK LIMITED       21256
# 58428                               VANQUIS BANK LIMITED       13245
# 59088                                  ZOPA BANK LIMITED       20751
#
#                                                  Address  PostCode  \
# 247                      92 Ann Street, Belfast, BT1 3HH   BT1 3HH
# ...

# %%
device_auth = DeviceCodeLoginAuthentication()

# %%
from powerbiclient.dataflows import DataflowClient

# %%
dataflow_id = "<your_dataflow_id>"
client = DataflowClient(device_auth)

dataflow = client.get_dataflow(dataflow_id)
entities = dataflow.get_entities()

# %%
group_id="73381072-b5c3-495a-a1b7-63b13bcd1087" #YOU HAVE TO PUT HERE YOUR POWER BI GROUP ID OR WORKSPACE ID
report_id="ccbf2a26-df15-48e1-aee8-eb87d773fc7a" #YOU HAVE TO PUT HERE YOUR POWER BI REPORT ID

report = Report(group_id=group_id, report_id=report_id, auth=device_auth)
report.set_size(1024, 1600)
output.enable_custom_widget_manager()

# %%
import pandas as pd

url = 'https://drive.google.com/file/d/10eWhPFRQ1J6ztEWbjTQjtInGYu94iVXn/view?usp=sharing'
df = pd.read_csv(url)

# %%
df

# %%
# Initialize an empty list to hold DataFrames
dfs = []

# Load and process each CSV file
for file_path in file_paths:
    # Load CSV
    df = pd.read_csv(file_path + ".csv")  # Add .csv to the URL



# Concatenate all DataFrames
combined_data = pd.concat(dfs, ignore_index=True)
